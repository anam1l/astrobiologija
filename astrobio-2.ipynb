# %% [markdown]
# astrobiologija - pca analiza

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

# %%
path_dints = 'jw02783002001_03103_00001-seg001_mirimage_x1dints.fits'
hduld = fits.open(path_dints)

print(hduld.info())
# Out:
# Filename: jw02783002001_03103_00001-seg001_mirimage_x1dints.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     261   ()
#   1  INT_TIMES     1 BinTableHDU     24   10R x 7C   [J, D, D, D, D, D, D]
#   2  EXTRACT1D     1 BinTableHDU    116   10R x 27C   [J, 388D, 388D, 388D, 388D, 388D, 388D, 388D, 388D, 388D, 388D, 388D, 388J, 388D, 388D, 388D, 388D, 388D, 388D, J, J, D, D, D, D, D, D]
#   3  ASDF          1 BinTableHDU     11   1R x 1C   [43646B]
# None

# %%
data = hduld["EXTRACT1D"].data
print(data.columns.names)

wavelength = data['WAVELENGTH']
flux = data['FLUX']
flux_err = data['FLUX_ERROR']
tdb_beg = data['TDB-BEG']
tdb_end = data['TDB-END']
npixels = data['NPIXELS']
int_num = data['INT_NUM']
# Out:
# ['INT_NUM', 'WAVELENGTH', 'FLUX', 'FLUX_ERROR', 'FLUX_VAR_POISSON', 'FLUX_VAR_RNOISE', 'FLUX_VAR_FLAT', 'SURF_BRIGHT', 'SB_ERROR', 'SB_VAR_POISSON', 'SB_VAR_RNOISE', 'SB_VAR_FLAT', 'DQ', 'BACKGROUND', 'BKGD_ERROR', 'BKGD_VAR_POISSON', 'BKGD_VAR_RNOISE', 'BKGD_VAR_FLAT', 'NPIXELS', 'N_ALONGDISP', 'SEGMENT', 'MJD-BEG', 'MJD-AVG', 'MJD-END', 'TDB-BEG', 'TDB-MID', 'TDB-END']

# %%
plt.figure(figsize=(8,5))
plt.plot(wavelength,flux)
plt.title('sve integracije odjednom')
plt.xlabel('Wavelength')
plt.ylabel('Flux')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6))

plt.imshow(flux,cmap ='Spectral',aspect='auto',)

plt.colorbar(label='flux')
plt.xlabel('wavelength')
plt.ylabel('index')

plt.title('heatmap flux za sve spektre u x1dints')
plt.tight_layout()
plt.grid(alpha = 0.2)
plt.show()

# %%
fig, axes = plt.subplots(2, 5, figsize=(16, 6), sharex=True, sharey=True)

axes = axes.flatten()

wvlngth = data['WAVELENGTH']
flx_list = data['FLUX']

for i in range(len(wvlngth)):
    axes[i].plot(wvlngth[i], flx_list[i])
    axes[i].grid(alpha=0.2)
    axes[i].set_title(i)

fig.supxlabel('Wavelength')
fig.supylabel('Flux')
plt.show()

# %%
wavelength = data['WAVELENGTH']
flux = data['FLUX']

print(flux.shape)
print(wavelength.shape)
# 10 lista sa 388 vrendnoscu na svakoj
# Out:
# (10, 388)
# (10, 388)

# %%
from sklearn.preprocessing import StandardScaler

X = flux
Y = wavelength

# %%
#provera vrednosti podataka
std_per_wavelength = np.std(X, axis=0)
print(np.where(std_per_wavelength == 0))

np.isnan(X).sum(), np.isinf(X).sum()

for i in range(10):
    print(X[i][5:].min(),X[i][5:].max())
# Out:
# (array([], dtype=int64),)
# -0.004282112175354265 0.005353869397248288
# -0.0013522969992292003 0.0071006520969880615
# -0.0011020519912226371 0.005536013471244188
# -0.0004948276955572071 0.005989009164629078
# -0.002125548889072955 0.006100369344149632
# -0.001976917237324476 0.005859965582628891
# -0.001048440831616612 0.004461440314168574
# -0.0021065899350021376 0.006640757362408274
# -0.0026635226898872218 0.004561542340135745
# -0.0014382578903856438 0.005575613118452606

# %%
#ciscenje NaN vrednosti

mask = ~np.isnan(X).any(axis=0)
print(mask.shape)

#print(np.isnan(X[2])) #- prvih pet vrednosti svake liste je NaN

X_clean = X[:, 5:]
Y_clean = Y[:,5:] # izbacujemo talasne duzine gde su fluksevi nan

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_clean)
Y_scaled = scaler.fit_transform(Y_clean)
# Out:
# (388,)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=6)
X_pca = pca.fit_transform(X_scaled)

# %%
import numpy as np

cum_var = np.cumsum(pca.explained_variance_ratio_)
print(cum_var)
# Out:
# [0.13713303 0.2703412  0.38969048 0.50191626 0.61019049 0.71259991]

# %% [raw]
# λ=λmin+x(λmax−λmin)
# ovo su sad normalizovani delovi gde su najznacajnije vrednosti
# sad trazimo koje su to zapravo talasne velicine i onda uzimamo vrednosti oko njih da bi napravili binove

# %%
pca_vals = np.array([0.13713303, 0.2703412, 0.38969048,
                      0.50191626, 0.61019049, 0.71259991])

lam_min = Y_clean.min()
lam_max = Y_clean.max()

bin_centers = lam_min + pca_vals * (lam_max - lam_min)

print('znacajne talasne duzine')
print(bin_centers) # u mikrometrima
# Out:
# znacajne talasne duzine
# [ 5.42360072  6.74471085  7.92837356  9.04138798 10.11521237 11.13087172]

# %%
bin_edges = np.zeros(len(bin_centers) + 1)

bin_edges[1:-1] = 0.5 * (bin_centers[1:] + bin_centers[:-1])
bin_edges[0] = lam_min
bin_edges[-1] = lam_max

print('ivice binova:')
print(bin_edges)
# Out:
# ivice binova:
# [ 4.06356525  6.08415578  7.3365422   8.48488077  9.57830018 10.62304205
#  13.98120117]

# %%
def rebin_spectrum(wavelength, flux, bin_edges):
    binned_flux = []

    for i in range(len(bin_edges) - 1):
        left = bin_edges[i]
        right = bin_edges[i + 1]

        mask = (wavelength >= left) & (wavelength < right)

        binned_flux.append(np.mean(flux[mask]))

    return np.array(binned_flux)

# %%
binned_flux = rebin_spectrum(Y_clean[0], X_clean[0], bin_edges)

# %%
print(binned)
# Out:
# [2.83614416e-05 4.91815790e-05 8.16531600e-05 1.11779555e-04
#  9.93159508e-05 6.72629836e-04]

# %%
tenzor = [None]*10

for i in range(10):
    binned_flux = rebin_spectrum(Y_clean[i], X_clean[i], bin_edges)
    tenzor[i] = list(zip(binned_flux, bin_edges))
    #X_bin.append(rebin_spectrum(Y_clean[i],X_clean[i],bin_edges))

# %%
print(tenzor)
# Out:
# [[(2.8361441608562782e-05, 4.063565254211426), (4.918157902833656e-05, 6.0841557836965805), (8.165316002622414e-05, 7.336542202393341), (0.00011177955476847179, 8.48488076873889), (9.931595084963326e-05, 9.57830017824948), (0.0006726298356770866, 10.623042045501709)], [(4.3366105285596496e-05, 4.063565254211426), (4.965206179815184e-05, 6.0841557836965805), (7.825429489082275e-05, 7.336542202393341), (0.00010399152110608512, 8.48488076873889), (0.00012869770627376041, 9.57830017824948), (0.0009808591582606441, 10.623042045501709)], [(3.018908591472013e-05, 4.063565254211426), (6.215870069426349e-05, 6.0841557836965805), (0.00010039402087610739, 7.336542202393341), (0.00011533935219260039, 8.48488076873889), (0.00010758850639258708, 9.57830017824948), (0.0007905431523006453, 10.623042045501709)], [(2.9264688872783672e-05, 4.063565254211426), (6.443801156655751e-05, 6.0841557836965805), (6.849245138207405e-05, 7.336542202393341), (9.004049155938683e-05, 8.48488076873889), (0.00010751127412779943, 9.57830017824948), (0.0007975048465873916, 10.623042045501709)], [(3.676166379095764e-05, 4.063565254211426), (5.2178260382255424e-05, 6.0841557836965805), (6.128989834042416e-05, 7.336542202393341), (9.991608723518663e-05, 8.48488076873889), (0.0001015291013923651, 9.57830017824948), (0.0007291088545248746, 10.623042045501709)], [(3.0416289613418938e-05, 4.063565254211426), (6.222780253426712e-05, 6.0841557836965805), (8.648174214453395e-05, 7.336542202393341), (0.00010917308065778898, 8.48488076873889), (0.00011966786738551624, 9.57830017824948), (0.000734910339842815, 10.623042045501709)], [(2.5238446894471466e-05, 4.063565254211426), (6.120485874851862e-05, 6.0841557836965805), (8.134806451794148e-05, 7.336542202393341), (9.425732008500992e-05, 8.48488076873889), (9.712594398220821e-05, 9.57830017824948), (0.0007823185162848985, 10.623042045501709)], [(3.0719354462738494e-05, 4.063565254211426), (6.032821891715128e-05, 6.0841557836965805), (8.273260750850928e-05, 7.336542202393341), (0.00010557998845224136, 8.48488076873889), (9.401997657092913e-05, 9.57830017824948), (0.0007470762050182106, 10.623042045501709)], [(3.18189166525423e-05, 4.063565254211426), (5.898929797049741e-05, 6.0841557836965805), (7.630790408664925e-05, 7.336542202393341), (0.0001017998690380229, 8.48488076873889), (0.00012795006228780972, 9.57830017824948), (0.0006542431768409142, 10.623042045501709)], [(2.1064964720741426e-05, 4.063565254211426), (6.989765619620463e-05, 6.0841557836965805), (7.49972184264606e-05, 7.336542202393341), (0.00014290542289138985, 8.48488076873889), (9.379928769609572e-05, 9.57830017824948), (0.000691676236611331, 10.623042045501709)]]

# %%
plt.figure(figsize=(8, 6))
tenzor_np = np.array(tenzor)
plt.imshow(tenzor_np[:, :, 0],cmap ='Spectral',aspect='auto',)

plt.colorbar(label='flux')
plt.xlabel('wavelength')
plt.ylabel('index')

plt.title('heatmap flux za PCA flux u x1dints')
plt.tight_layout()
plt.grid(alpha = 0.2)
plt.show()

# %% [raw]
# pip install QhX

# %%
import QhX
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
from QhX.algorithms.wavelets.wwtz import *
from QhX import plots
from QhX.utils import *

# %%
tt = tenzor_np[:, :, 1] #pca talasne duzine
#print(tt)
yy = tenzor_np[:, :, 0] #pca znacajne flux vrednosti 
#print(yy)

# %%
wwz_matrix, corr, extent = hybrid2d(tt, yy, 10, 6, minfq=lam_min,maxfq=lam_max)
# Out:
# *** Starting Weighted Wavelet Z-transform ***
#
# Pseudo sample frequency (median) is  0.871
# largest tau window is  [0. 0. 0. 0. 0. 0.]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 wwz_matrix, corr, extent = hybrid2d(tt, yy, 10, 6, minfq=lam_min,maxfq=lam_max)
#
# File ~/.local/lib/python3.11/site-packages/QhX/algorithms/wavelets/wwtz.py:222, in hybrid2d(tt, mag, ntau, ngrid, minfq, maxfq, parallel, f, method)
#     178 """
#     179 Perform a hybrid 2D analysis involving WWZ (Weighted Wavelet Z-transform) and auto-correlation on light curve data.
#     180
#    (...)
#     215 >>> wwz_result, acorr_result, freq_extent = hybrid2d(tt, mag, 100, 50, 0.1, 1.0)
#     216 """
#     218 # Function implementation
#     219 # ...
#     220
#     221 # Perform WWZ analysis on the data using the wwt function
# --> 222 wwz_matrix = wwt1(tt, mag, ntau, ngrid, minfq, maxfq, parallel, f, method)
#     224 # Auto-correlate the WWZ matrix
#     225 # np.rot90 rotates the matrix by 90 degrees to align time and frequency axes as needed
#     226 corr = correlation_nd(np.rot90(wwz_matrix[2]), np.rot90(wwz_matrix[2]))
#
# File ~/.local/lib/python3.11/site-packages/QhX/algorithms/wavelets/wwtz.py:164, in wwt1(tt, mag, ntau, ngrid, minfq, maxfq, parallel, f, method)
#     161 ntau, params, decay_constant, parallel = inp_param(ntau, ngrid, minfq, maxfq, parallel, f)
#     163 # Perform WWZ analysis using libwwz library
# --> 164 return libwwz_wwt(timestamps=tt, magnitudes=mag,
#     165                   time_divisions=ntau,
#     166                   freq_params=params,
#     167                   decay_constant=decay_constant,
#     168                   method=method,
#     169                   parallel=parallel)
#
# File ~/.local/lib/python3.11/site-packages/libwwz/wwz.py:290, in wwt(timestamps, magnitudes, time_divisions, freq_params, decay_constant, method, parallel)
#     288     output = np.empty([ntau, nfreq, 6])
#     289     for i, dtau in enumerate(tau):
# --> 290         output[i] = tau_loop(dtau)
#     292 # Format the output to be in len(tau) by len(freq) matrix for each value with correct labels
#     294 tau_mat: np.ndarray = output[:, :, 0].reshape([ntau, nfreq])
#
# File ~/.local/lib/python3.11/site-packages/libwwz/wwz.py:195, in wwt.<locals>.tau_loop(dtau)
#     191 dweight: float = np.exp(-1 * decay_constant * dz ** 2)
#     193 # get upper triangular matrix of the weights and vector
#     194 # These are used later to calculate Neff, DWT, DWP, etc in the paper
# --> 195 if dweight > 10 ** -9:
#     196     cos_dz: float = np.cos(dz)
#     197     sin_dz: float = np.sin(dz)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
tenzor_t = tenzor_np.transpose()
tt_t = tenzor_t[:, :, 1] #pca talasne duzine
#print(tt)
yy_t = tenzor_t[:, :, 0] #pca znacajne flux vrednosti 
#print(yy)

# %%
wwz_matrix, corr, extent = hybrid2d(tt_t, yy_t, 10, 6, minfq=lam_min,maxfq=lam_max)
# Out:
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  2
# Pseudo sample frequency (median) is  1.913
# largest tau window is  [ 4.064  6.084  7.336  8.485  9.578 10.622]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 wwz_matrix, corr, extent = hybrid2d(tt_t, yy_t, 10, 6, minfq=lam_min,maxfq=lam_max)
#
# File ~/.local/lib/python3.11/site-packages/QhX/algorithms/wavelets/wwtz.py:222, in hybrid2d(tt, mag, ntau, ngrid, minfq, maxfq, parallel, f, method)
#     178 """
#     179 Perform a hybrid 2D analysis involving WWZ (Weighted Wavelet Z-transform) and auto-correlation on light curve data.
#     180
#    (...)
#     215 >>> wwz_result, acorr_result, freq_extent = hybrid2d(tt, mag, 100, 50, 0.1, 1.0)
#     216 """
#     218 # Function implementation
#     219 # ...
#     220
#     221 # Perform WWZ analysis on the data using the wwt function
# --> 222 wwz_matrix = wwt1(tt, mag, ntau, ngrid, minfq, maxfq, parallel, f, method)
#     224 # Auto-correlate the WWZ matrix
#     225 # np.rot90 rotates the matrix by 90 degrees to align time and frequency axes as needed
#     226 corr = correlation_nd(np.rot90(wwz_matrix[2]), np.rot90(wwz_matrix[2]))
#
# File ~/.local/lib/python3.11/site-packages/QhX/algorithms/wavelets/wwtz.py:164, in wwt1(tt, mag, ntau, ngrid, minfq, maxfq, parallel, f, method)
#     161 ntau, params, decay_constant, parallel = inp_param(ntau, ngrid, minfq, maxfq, parallel, f)
#     163 # Perform WWZ analysis using libwwz library
# --> 164 return libwwz_wwt(timestamps=tt, magnitudes=mag,
#     165                   time_divisions=ntau,
#     166                   freq_params=params,
#     167                   decay_constant=decay_constant,
#     168                   method=method,
#     169                   parallel=parallel)
#
# File ~/.local/lib/python3.11/site-packages/libwwz/wwz.py:290, in wwt(timestamps, magnitudes, time_divisions, freq_params, decay_constant, method, parallel)
#     288     output = np.empty([ntau, nfreq, 6])
#     289     for i, dtau in enumerate(tau):
# --> 290         output[i] = tau_loop(dtau)
#     292 # Format the output to be in len(tau) by len(freq) matrix for each value with correct labels
#     294 tau_mat: np.ndarray = output[:, :, 0].reshape([ntau, nfreq])
#
# File ~/.local/lib/python3.11/site-packages/libwwz/wwz.py:195, in wwt.<locals>.tau_loop(dtau)
#     191 dweight: float = np.exp(-1 * decay_constant * dz ** 2)
#     193 # get upper triangular matrix of the weights and vector
#     194 # These are used later to calculate Neff, DWT, DWP, etc in the paper
# --> 195 if dweight > 10 ** -9:
#     196     cos_dz: float = np.cos(dz)
#     197     sin_dz: float = np.sin(dz)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
rezultati_wwz = []
rezultati_corr = []
rezultati_extent = []

for i in range(10):
    tt = tenzor_np[i, :, 1]
    yy = tenzor_np[i, :, 0]
    
    # Poziv funkcije za svaki red pojedinačno
    w_mat, c, ext = hybrid2d(tt, yy, ntau=10, ngrid=6, minfq=lam_min, maxfq=lam_max)
    rezultati_wwz.append(w_mat)
    rezultati_corr.append(c)
    rezultati_extent.append(ext)
# Out:
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform
#
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform
#
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform
#
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform
#
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform
#
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform
#
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform
#
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform
#
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform
#
# *** Starting Weighted Wavelet Z-transform ***
#
# adjusted time_divisions to:  6
# Pseudo sample frequency (median) is  0.871
# largest tau window is  1.312
# 0.01 seconds has passed to complete Weighted Wavelet Z-transform

# %%
for i in range(len(rezultati_wwz)):
    plots.plt_freq_heatmap(rezultati_corr[i], rezultati_extent[i])

# %%
from QhX.calculation import *
for i in range(len(rezultati_corr)):
    peaks0, hh0, r_periods0[i], up0, low0 = periods(10, rezultati_corr[i], 6, plot=True, minfq=lam_min, maxfq=lam_max)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[120], line 3
#       1 from QhX.calculation import *
#       2 for i in range(len(rezultati_corr)):
# ----> 3     peaks0, hh0, r_periods0[i], up0, low0 = periods(10, rezultati_corr[i], 6, plot=True, minfq=lam_min, maxfq=lam_max)
#
# File ~/.local/lib/python3.11/site-packages/QhX/calculation.py:140, in periods(lcID, data, ngrid, plot, save, peakHeight, prominence, minfq, maxfq, xlim)
#     138     plt.xlim(xlim)
#     139 plt.plot(xax, np.abs(yax))
# --> 140 plt.axvline(xax[peaks[0]], ymin=0, ymax=1, linestyle='--', color='k')
#     141 plt.title(str(lcID))
#     142 plt.xlabel(r'Frequency [day$^{-1}$]')
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# Write down obtained results
for j in range(len(r_periods0)):
    print("Period: %6.3f, upper error : %5.2f  lower error : %5.2f"% (r_periods0[j], up0[j], low0[j]) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 3
#       1 # Write down obtained results
#       2 for j in range(10):
# ----> 3     print("Period: %6.3f, upper error : %5.2f  lower error : %5.2f"% (r_periods0[j], up0[j], low0[j]) )
#
# NameError: name 'r_periods0' is not defined
